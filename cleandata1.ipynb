# %%
import pandas as pd

# Đọc file CSV
file_path = "UN_VNM_Seafood_Export_ByPartner_HS03_1604_1605_2015_2023.csv.csv"

df = pd.read_csv(file_path, encoding="latin1")

# Các cột cần giữ
columns_keep = [
    "refYear",
    "refMonth",
    "reporterDesc",
    "flowDesc",
    "partnerDesc",
    "classificationCode",
    "cmdCode",
    "cmdDesc",
    "qty",
    "qtyUnitAbbr",
    "netWgt",
    "fobvalue",
    "primaryValue"
]

# Lọc dữ liệu
df_filtered = df[columns_keep]

# Xuất file mới
output_file = "Seafood_Export_ByPartner_Filtered.csv"
df_filtered.to_csv(output_file, index=False, encoding="utf-8-sig")

print("Đã xuất file:", output_file)
print(df_filtered.head())
# Out:
# Đã xuất file: Seafood_Export_ByPartner_Filtered.csv
#    refYear  refMonth reporterDesc  flowDesc  partnerDesc classificationCode  \
# C       52      2015            X         0            0                 HS
# C       52      2015            X        12            0                 HS
# C       52      2015            X        20            0                 HS
# C       52      2015            X        24            0                 HS
# C       52      2015            X        31            0                 HS
#
#                                              cmdCode  cmdDesc    qty  \
# C  Fish and crustaceans, molluscs and other aquat...        2  False
# C  Fish and crustaceans, molluscs and other aquat...        2  False
# C  Fish and crustaceans, molluscs and other aquat...        2  False
# C  Fish and crustaceans, molluscs and other aquat...        2  False
# C  Fish and crustaceans, molluscs and other aquat...        2  False
#
#    qtyUnitAbbr  netWgt      fobvalue  primaryValue
# C          NaN   False  4.838124e+09             0
# C          NaN   False  8.049300e+06             0
# C          NaN   False  1.820291e+06             0
# C          NaN   False  2.777495e+06             0
# C          NaN   False  1.308000e+03             0
